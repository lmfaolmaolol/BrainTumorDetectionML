# %%
# TRAINING PHASE


from google.colab import drive

drive.mount('/content/gdrive') # connecting google colab to google drive

ROOT_DIR = '/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8' # path to the dataset

# !pip install ultralytics

import os

import locale

from ultralytics import YOLO

learning_rates=[0.01,0.001,0.0001]
batch_sizes=[16,32]
epochs=[50,100]

# to check for the best combination of hyper parameters, I ran 3 for loops to check and train in all combinations of the hyperparameters

for lr in learning_rates:
  for bs in batch_sizes:
    for ep in epochs:
      model = YOLO("yolov8n.yaml")
      results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=ep, batch=bs, lr0=lr)
      # to save the training data in google drive
      locale.getpreferredencoding = lambda: "UTF-8"

      # !scp -r /content/runs '/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8'

# %%
#CODE TO GET FINAL TRAINED MODEL

from google.colab import drive

drive.mount('/content/gdrive')

ROOT_DIR = '/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8'

# !pip install ultralytics

import os

import locale

from ultralytics import YOLO

# After checking the reults of the previous cases, learning rate 0.001 and batch size 16 performed the best,
# so i trained another model with same learning rate and batch size but an epoch of 200

learning_rates=[0.001]
batch_sizes=[16]
epochs=[200]

for lr in learning_rates:
  for bs in batch_sizes:
    for ep in epochs:
      model = YOLO("yolov8n.yaml")
      results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=ep, batch=bs, lr0=lr)

      locale.getpreferredencoding = lambda: "UTF-8"

      # !scp -r /content/runs '/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8'
# Out:
# Mounted at /content/gdrive
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.4/881.4 kB 41.0 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.3 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#EVALUATING PHASE



from google.colab import drive

drive.mount('/content/gdrive')

ROOT_DIR = '/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8'

# !pip install ultralytics

import os

from ultralytics import YOLO

model=YOLO("/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/runs/detect/train/weights/best.pt")# path to the best.pt of a specific model

results = model.val(data="/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/data.yaml", save=True)

print("F1 score:", results.box.f1)# collecting f1 scores of all models so i can compare between them


model=YOLO("/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/runs/detect/train2/weights/best.pt")

results = model.val(data="/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/data.yaml", save=True)

print("F1 score:", results.box.f1)


model=YOLO("/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/runs/detect/train3/weights/best.pt")

results = model.val(data="/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/data.yaml", save=True)

print("F1 score:", results.box.f1)


model=YOLO("/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/runs/detect/train4/weights/best.pt")

results = model.val(data="/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/data.yaml", save=True)

print("F1 score:", results.box.f1)


model=YOLO("/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/runs/detect/train5/weights/best.pt")

results = model.val(data="/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/data.yaml", save=True)

print("F1 score:", results.box.f1)


model=YOLO("/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/runs/detect/train6/weights/best.pt")

results = model.val(data="/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/data.yaml", save=True)

print("F1 score:", results.box.f1)


model=YOLO("/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/runs/detect/train7/weights/best.pt")

results = model.val(data="/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/data.yaml", save=True)

print("F1 score:", results.box.f1)


model=YOLO("/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/runs/detect/train8/weights/best.pt")

results = model.val(data="/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/data.yaml", save=True)

print("F1 score:", results.box.f1)


model=YOLO("/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/runs/detect/train9/weights/best.pt")

results = model.val(data="/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/data.yaml", save=True)

print("F1 score:", results.box.f1)


model=YOLO("/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/runs/detect/train10/weights/best.pt")

results = model.val(data="/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/data.yaml", save=True)

print("F1 score:", results.box.f1)
# Out:
# Mounted at /content/gdrive
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.4/881.4 kB 19.3 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.3 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 186 layers, 2,684,563 parameters, 0 gradients, 6.8 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 26.3MB/s]
# val: Scanning /content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/valid/labels.cache... 114 images, 0 backgrounds, 0 corrupt: 100%|██████████| 114/114 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:38<00:00,  4.77s/it]
# ...

# %%
#TESTING PHASE


# Since the last test case(lr=0.001,batch size=16, epochs=200) had the highest f1 score i considered it to be the final trained model and used it for testing
from google.colab import drive

drive.mount('/content/gdrive')

ROOT_DIR = '/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8'

# !pip install ultralytics

import os

import locale

from ultralytics import YOLO

model=YOLO("/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/runs/detect/train/weights/best.pt")# path to the trained model
results = model.predict(source="/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/test/images", save=True)

locale.getpreferredencoding = lambda: "UTF-8"

# !scp -r /content/runs '/content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ...
#
# image 1/56 /content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/test/images/Brain-Tumor-Overview_mp4-0017_jpg.rf.4b4a9d7c48c7059bd95cab43896c27d3.jpg: 640x640 1 tumor, 186.0ms
# image 2/56 /content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/test/images/Brain-Tumor-Overview_mp4-0113_jpg.rf.748bd08d7dc85545a47e9374e836dd1b.jpg: 640x640 1 tumor, 176.7ms
# image 3/56 /content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/test/images/Brain-Tumor-Overview_mp4-0125_jpg.rf.8f3f32e3bc76b73af1e80761af3ee1c6.jpg: 640x640 1 tumor, 176.7ms
# image 4/56 /content/gdrive/My Drive/brain tumor/brain tumor detection.v2-mahitha.yolov8/test/images/Brain-Tumor-Overview_mp4-0129_jpg.rf.60e041d6464a8825ad6d5dd5c669cbaa.jpg: 640x640 1 tumor, 178.0ms
# ...
